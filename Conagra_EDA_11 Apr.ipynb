# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
smeat_aggsales = pd.read_csv('smeat_aggsales_plus_att.csv')
# Out:
# C:\Users\rxn230005\AppData\Local\Temp\ipykernel_13196\4228470117.py:1: DtypeWarning: Columns (75,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   smeat_aggsales = pd.read_csv('smeat_aggsales_plus_att.csv')

# %%
smeat_aggsales.head()
# Out:
#                         Geography                  Time  \
# 0  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 1  Total US - Multi Outlet + Conv  Week Ending 01-19-20
# 2  Total US - Multi Outlet + Conv  Week Ending 01-26-20
# 3  Total US - Multi Outlet + Conv  Week Ending 02-02-20
# 4  Total US - Multi Outlet + Conv  Week Ending 02-09-20
#
#                                            Product_x  UPC 13 digit  \
# 0  MATCH FROZEN GROUND BEEF MEAT SUBSTITUTE GROUN...  886844017011
# 1  MATCH FROZEN GROUND BEEF MEAT SUBSTITUTE GROUN...  886844017011
# 2  MATCH FROZEN GROUND BEEF MEAT SUBSTITUTE GROUN...  886844017011
# 3  MATCH FROZEN GROUND BEEF MEAT SUBSTITUTE GROUN...  886844017011
# 4  MATCH FROZEN GROUND BEEF MEAT SUBSTITUTE GROUN...  886844017011
#
#    Unit Sales  Unit Sales No Merch  Unit Sales Any Merch  \
# 0   49.378093            49.378093                   NaN
# 1   48.274877            48.274877                   NaN
# ...

# %%
smeat_aggsales.shape
# Out:
# (991780, 78)

# %%
# Getting the best performing Gardein products yearwise

# %%
smeat_aggsales[smeat_aggsales['Brand Franchise Name']=='GARDEIN'].groupby(['Year','Product_x']).sum()[['Unit Sales','Volume Sales','Dollar Sales']]
# Out:
#                                                            Unit Sales  \
# Year Product_x
# 20   GARDEIN FROZEN BEEF MEAT SUBSTITUTE TIP 9 OZ - ...  2.099447e+06
#      GARDEIN FROZEN CHICKEN POULTRY SUBSTITUTE STRIP...  1.861304e+06
#      GARDEIN FROZEN CHICKEN SCALLOPINI POULTRY SUBST...  3.690122e+05
#      GARDEIN FROZEN CHIPOTLE BLACK BEAN MEAT SUBSTIT...  1.590971e+06
#      GARDEIN FROZEN CHIPOTLE BLACK BEAN MEAT SUBSTIT...  5.053239e+03
# ...                                                               ...
# 24   GARDEIN ULTIMATE PLANT BASED FROZEN ORIGINAL ME...  6.388423e+04
#      GARDEIN ULTIMATE PLANT BASED FROZEN REGULAR MEA...  6.255320e+04
#      GARDEIN ULTIMATE PLANT BASED FROZEN REGULAR MEA...  4.392008e+04
#      GARDEIN ULTIMATE PLANT BASED FROZEN REGULAR PLA...  2.177043e+05
#      GARDEIN ULTIMATE PLANT BASED FROZEN SPICY ITALI...  2.509360e+03
#
#                                                          Volume Sales  \
# Year Product_x
# ...

# %%
smeat_aggsales[smeat_aggsales['Brand Franchise Name']=='GARDEIN'].groupby(['Year','Product_x']).sum()[['Unit Sales','Volume Sales','Dollar Sales']].to_excel('Gardein_productwise_aggsales_yearwise.xlsx')

# %%
# Getting the best performing Impossible, Morningstar & Beyond products yearwise

# %%
smeat_aggsales[smeat_aggsales['Brand Franchise Name']=='IMPOSSIBLE'].groupby(['Year','Product_x']).sum()[['Unit Sales','Volume Sales','Dollar Sales']].to_excel('Impossible_productwise_aggsales_yearwise.xlsx')

# %%
smeat_aggsales[smeat_aggsales['Brand Franchise Name']=='MORNINGSTAR FARMS'].groupby(['Year','Product_x']).sum()[['Unit Sales','Volume Sales','Dollar Sales']].to_excel('MORNINGSTAR_productwise_aggsales_yearwise.xlsx')

# %%
smeat_aggsales[(smeat_aggsales['Brand Franchise Name']=='BEYOND CHICKEN') & 
(smeat_aggsales['Brand Franchise Name']=='BEYOND MEAT') &
(smeat_aggsales['Brand Franchise Name']=='BEYOND STACK BURGER') &
(smeat_aggsales['Brand Franchise Name']=='BEYOND STEAK') &
(smeat_aggsales['Brand Franchise Name']=='BEYOND POPCORN CHICKEN')
].groupby(['Year','Product_x']).sum()[['Unit Sales','Volume Sales','Dollar Sales']].to_excel('BEYOND_productwise_aggsales_yearwise.xlsx')
